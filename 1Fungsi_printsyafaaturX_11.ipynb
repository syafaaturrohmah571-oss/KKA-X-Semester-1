# %% [markdown]
# <a href="https://colab.research.google.com/github/syafaaturrohmah571-oss/KKA-X-Semester-1/blob/main/1Fungsi_printsyafaaturX_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:syfaaturrohmah
#
# Kelas:X-11
#
# No absen:33

# %% [markdown]
# #Mebampilkan teks bebas

# %%
print("syfaaturrohmah")
# Out:
# syfaaturrohmah

# %% [markdown]
# #Menampilakan teks bebas dan nama variabel

# %%
nama_saudara = "Dewi anggraeni"
print(nama_saudara)
# Out:
# Dewi anggraeni

# %%
Jumlah_saudara = 4
print(Jumlah_saudara)
# Out:
# 4

# %% [markdown]
# #Menampilkan teks bebas dan nilaivariabel mengggunakan tanda koma

# %%
print("saya memilik saudara sebanyak" , Jumlah_saudara , "nama saudara saya adalah " , nama_saudara)
# Out:
# saya memilik saudara sebanyak 4 nama saudara saya adalah  Dewi anggraeni

# %% [markdown]
# #Menampilkan teks bebas dan nilai variabel menggunakan tanda plus

# %%
print("saya memilik saudara sebanyak" + str (Jumlah_saudara) + "." + "nama saudara saya adalah " + nama_saudara + ".")
# Out:
# saya memilik saudara sebanyak4.nama saudara saya adalah Dewi anggraeni.

# %% [markdown]
# #Menampilkan teks bebas dan nilai variabel menggunakan tanda f sting

# %%
print(f"saya memiliki saudara sebanyak {Jumlah_saudara} .Nama saudara saya adalah {nama_saudara} .")
# Out:
# saya memiliki saudara sebanyak 4 .Nama saudara saya adalah Dewi anggraeni .

# %%
print("Nama:syfaaturrohmah")
print("kelas: x.11")
print("No.absen:33")
# Out:
# Nama:syfaaturrohmah
# kelas: x.11
# No.absen:33

# %%
print("Nama:syfaaturrohmah\nkelas: x.11\nNo.absen:33")
# Out:
# Nama:syfaaturrohmah
# kelas: x.11
# No.absen:33

# %% [markdown]
# #Escape character

# %%
print("""Nama\t\t:syfaaturrohmah
kelas\t\t:x.11
No.absen\t: 33""")
# Out:
# Nama		:syfaaturrohmah
# kelas		:x.11
# No.absen	: 33

# %%
print("syfaaturrohmah")
# Out:
# syfaaturrohmah

# %%
print('syfaaturrohmah')
# Out:
# syfaaturrohmah

# %%
print('Habib ja\'far')
# Out:
# Habib ja'far

# %%
print("Habib ja'far")
# Out:
# Habib ja'far

# %%
print ('Bu shinta berkata ,"Harap fokus menyimak!".')
# Out:
# Bu shinta berkata ,"Harap fokus menyimak!".

# %%
print("Bu shinta berkata ,\"Harap fokus menyimak!\".")
# Out:
# Bu shinta berkata ,"Harap fokus menyimak!".

# %%
print("Lokasi penyimpanan tugas KKA di D:\\Man Demak \\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\Man Demak \KKA\Tugas

# %% [markdown]
# #Fungsi parameter

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 = "Adzka"
nama_siswa_3 = "Haidar"

print(nama_siswa_1,nama_siswa_2, sep="-")
# Out:
# Daffanes-Adzka

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 = "Adzka"
nama_siswa_3 = "Haidar"

print(nama_siswa_3,nama_siswa_2,nama_siswa_1,nama_siswa_2, sep="*")
# Out:
# Haidar*Adzka*Daffanes*Adzka

# %%
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print(nama_siswa_1,nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1, end ="-")
print(nama_siswa_2)
# Out:
# Daffanes-Adzka

# %% [markdown]
# #Latihan soal

# %% [markdown]
# Gunakan parameter end untuk menampilkan tulisan sebagai berikut:
# Haidar#Adzka#Daffanes##Adzka

# %%
print(nama_siswa_3, end="#")
print(nama_siswa_2, end="#")
print(nama_siswa_1, end="#")
print(nama_siswa_2)
# Out:
# Haidar#Adzka#Daffanes#Adzka
