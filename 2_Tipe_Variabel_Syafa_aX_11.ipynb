# %% [markdown]
# <a href="https://colab.research.google.com/github/syafaaturrohmah571-oss/KKA-X-Semester-1/blob/main/2_Tipe_Variabel_Syafa_aX_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:syafaaturrohmah
#
# Kelas:X.11
#
# No. Aben:33

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("syafaaturrohmah571@gmail.com")
print("syafaaturrohmah571@gmail.com")
print("syafaaturrohmah571@gmail.com")
# Out:
# syafaaturrohmah571@gmail.com
# syafaaturrohmah571@gmail.com
# syafaaturrohmah571@gmail.com

# %%
email_user_1 = "syafaaturrohmah571@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# syafaaturrohmah571@gmail.com
# syafaaturrohmah571@gmail.com
# syafaaturrohmah571@gmail.com

# %% [markdown]
# #Peraturan penanamaan variabel

# %%
#Hanya diperbolehkan menggunakan huruf, angka, dan underscore
email user 2 = "bobbyaliando@gemail.com"
# Out:
#   File "/tmp/ipython-input-3910310120.py", line 2
#     email user 2 = "bobbyaliando@gemail.com"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser2 ="bobbyaliando@gemail.com"

print(emailuser2)
# Out:
# bobbyaliando@gemail.com

# %%
#Tidak boleh didahului angka
3_email_user = "Willytaulany@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-2431130605.py", line 2
#     3_email_user = "Willytaulany@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 = "willytaulany@gmail.com"

print(email_user_3)
# Out:
# willytaulany@gmail.com

# %%
#Tidak boleh menggunakan kata kunci python
for = "HimamHimawan@gmail.com"

print(for)
# Out:
#   File "/tmp/ipython-input-2856673093.py", line 2
#     for = "HimamHimawan@gmail.com"
#         ^
# SyntaxError: invalid syntax

# %%
For = "HimamHimawan@gmail.com"

print(For)
# Out:
# HimamHimawan@gmail.com

# %%
print = "Juliawati@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1948412904.py in <cell line: 0>()
#       1 print = "Juliawati@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Juliawati@gmail.com"

print(Print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3159628512.py in <cell line: 0>()
#       1 Print = "Juliawati@gmail.com"
#       2
# ----> 3 print(Print)
#
# TypeError: 'str' object is not callable

# %%
#tidak eror tapi dianjurkan harus deskriptif
_ = "Devandraarnoldi@gmail.com"

# %%
print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3119395983.py in <cell line: 0>()
# ----> 1 print(_)
#
# TypeError: 'str' object is not callable

# %%
_ = "haidarhalilintar@gmail.com"

# %%
print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3119395983.py in <cell line: 0>()
# ----> 1 print(_)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #Assigment

# %%
#Single assigment
nama_mahasiswa_1 : "Alexandrio"

print(nama_mahasiswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-307048971.py in <cell line: 0>()
#       2 nama_mahasiswa_1 : "Alexandrio"
#       3
# ----> 4 print(nama_mahasiswa_1)
#
# NameError: name 'nama_mahasiswa_1' is not defined

# %%
#Multiple Asiggnment

# nama_barang_1 = "rinso"
# nama_barang_2 = "molto"

nama_barang_1, nama_barang_2, = "rinso", "molto"

print(nama_barang_1)
print(nama_barang_2)
# Out:
# rinso
# molto

# %%
#Assignment yang sama
nilai_devandra = nilai_willy = nilai_dzaki = 100

print(nilai_devandra)
print(nilai_willy)
print(nilai_dzaki)
# Out:
# 100
# 100
# 100

# %%
#Menimpa/Mengubah Nilai Variabel
nilai_himam = 95

# %%
print(nilai_himam)
# Out:
# 95

# %%
nilai_himam = 100

# %%
print(nilai_himam)
# Out:
# 100

# %% [markdown]
# #Penggunaan Operator di Python

# %%
#Tanpa Variabel
print(20+3)
# Out:
# 23

# %%
#Operand disimpan ke dalam variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

print(roti_swiss_alex + roti_swiss_nazril)
# Out:
# 23

# %%
#Hasil operasi disimpan ke dalam variabel
jumlah_roti_swiss = 20+3

print(jumlah_roti_swiss)
# Out:
# 23

# %%
#Operand dan hasil operasi disimpan ke variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

jumlah_roti_swiss = roti_swiss_alex + roti_swiss_nazril

print(jumlah_roti_swiss)
# Out:
# 23

# %% [markdown]
# #Latihan soal

# %%
#soal no. 1 (Tanpa variabel)
print(24 * 3)
# Out:
# 72

# %%
#soal no. 2(Hasil operasi di simpan ke dalam variabel)
Total_jumlah_botol = 24 *3

# %%
#soal no.3 (Operand disimpan kedalam variabel)
Banyak_botol_per_kardus = 24
Jumlah_kardus = 3

print(Banyak_botol_per_kardus *
Jumlah_kardus)
# Out:
# 72

# %%
#soal no.4 (Operand dan hasil operasi di simpan ke variabel)
Banyak_botol_per_kardus = 24
Jumlah_kardus = 3

Total_jumlah_botol = Banyak_botol_per_kardus * Jumlah_kardus

print(Total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Operator Aritmatika

# %%
buku_tulis_himam = 55
buku_tulis_vico = 15

# %%
#penjumlahan
total_buku_tulis = buku_tulis_himam + buku_tulis_vico
print(total_buku_tulis)
# Out:
# 70

# %%
#pengurangan

selisi_buku_tulis = buku_tulis_himam - buku_tulis_vico
print(selisi_buku_tulis)
# Out:
# 40

# %%
#perkalian
jumlah_kardus_buku_tulis = 3
isi_buku_tulis_perkardus = 10

total_buku_tulis = jumlah_kardus_buku_tulis * isi_buku_tulis_perkardus

print(total_buku_tulis)
# Out:
# 30

# %%
#pembagian
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis / jumlah_anak_yatim

print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3.3333333333333335

# %%
#pembagian bulat
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis // jumlah_anak_yatim

print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3

# %%
#sisa bagi
sisa_buku_tulis = total_buku_tulis % jumlah_anak_yatim
print(sisa_buku_tulis)
# Out:
# 3

# %%
#perpangkatan

sisi= 5

luas_persegi = sisi ** 2
print(luas_persegi)
# Out:
# 25

# %%
luas_persegi = 36

sisi = luas persegi ** (1/2)
print(sisi)
# Out:
#   File "/tmp/ipython-input-1159648638.py", line 3
#     sisi = luas persegi ** (1/2)
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Latihan soal

# %%
#soal no.1 (penjumlahan)
Dina_memiliki_apel = 8
ibu_memberi_apel = 5

jumlah_apel_Dina = Dina_memiliki_apel + ibu_memberi_apel
print(jumlah_apel_Dina)
# Out:
# 13

# %%
#soal no.2 (pengurangan)
petani_memetik_mangga = 30
mangga_yang_dijual = 12

mangga_yang_tersisa = petani_memetik_mangga - mangga_yang_dijual
print(mangga_yang_tersisa)
# Out:
# 18

# %%
#soal no.3 (perkalian)
jumlah_meja = 6
setiap_meja_ditempati_siswa = 4

total_jeruk_setiap_keranjang = jumlah_meja * setiap_meja_ditempati_siswa
print(total_jeruk_setiap_keranjang)
# Out:
# 24

# %%
#soal no.4 (pembagian)
jumlah_jeruk = 28
jumlah_keranjang = 7

total_jeruk_setiap_keranjang =jumlah_jeruk /jumlah_keranjang
print(total_jeruk_setiap_keranjang)
# Out:
# 4.0

# %%
#soal no.5 (sisa bagi)
ayah_membeli_donat = 25
jumlah_anak = 6

total_donat_yang_tersisa = ayah_membeli_donat//jumlah_anak
print(total_donat_yang_tersisa)
# Out:
# 4

# %%
#soal no.6 (perpangkat)

sisi = 7

luas_taman = sisi**2
print(luas_taman)
# Out:
# 49

# %% [markdown]
# #Tipe variabel

# %%
usia = 8

print(usia)
type(usia)
# Out:
# 8
# int

# %%
berat_badan = 7.5

type(berat_badan)
# Out:
# float

# %%
nama = "Dzakki"

type(nama)
# Out:
# str

# %%
lulus = True

type(lulus)
# Out:
# bool

# %%
titik_koordinat = -5
type(titik_koordinat)
# Out:
# int

# %%
titik_koordinat_bintang = -10.0
type(titik_koordinat_bintang)
# Out:
# float

# %% [markdown]
# #Konversi Tipe Data

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = float(usia)
print(usia)
type(usia)
# Out:
# 7.0
# float

# %%
berat_badan = 72.5
print(berat_badan)
type(berat_badan)
# Out:
# 72.5
# float

# %%
berat_badan = int(berat_badan)
print(berat_badan)
type(berat_badan)
# Out:
# 72
# int

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = str(usia)
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus = 1
print(lulus)
type(lulus)
# Out:
# 1
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# True
# bool

# %%
lulus = 0
print(lulus)
type(lulus)
# Out:
# 0
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# False
# bool
